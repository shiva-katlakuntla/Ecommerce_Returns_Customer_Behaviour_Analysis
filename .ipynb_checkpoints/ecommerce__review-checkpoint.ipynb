# %%
import pandas as pd
import numpy as np

# %%
reviews = pd.read_csv ("/content/reviews.csv")
reviews
# Out:
#        review_id  order_id  customer_id  product_id  rating  \
# 0        9500001   9220697     118258.0       59172       4
# 1        9500002   9009543     132165.0       59887       3
# 2        9500003   9193066     120679.0       51845       4
# 3        9500004   9101273     116027.0       57357       4
# 4        9500005   9019435     149944.0       56008       4
# ...          ...       ...          ...         ...     ...
# 99995    9599996   9086153     113122.0       50037       4
# 99996    9599997   9064441     106534.0       57853       5
# 99997    9513545   9124450     109506.0       58897       3
# 99998    9599999   9211156          NaN       57929       3
# 99999    9600000   9193474          NaN       55101       3
#
#                                 review_text review_date
# 0      Great product! Exactly as described.  16-06-2023
# 1         Average product, nothing special.  21-06-2023
# 2             Customer support was helpful.  02-11-2023
# 3            Poor quality, not recommended.  19-06-2023
# 4         Average product, nothing special.  11-08-2024
# ...                                     ...         ...
# 99995   Delivered on time, quality is good.  25-04-2025
# 99996        Would not recommend to anyone.  12-10-2023
# 99997  Great product! Exactly as described.  12-02-2024
# 99998  Not as described, very disappointed.  27-06-2023
# 99999  Not as described, very disappointed.  29-07-2023
#
# [100000 rows x 7 columns]

# %%
reviews.isnull().sum()
# Out:
# review_id         0
# order_id          0
# customer_id    2957
# product_id        0
# rating            0
# review_text    4845
# review_date       0
# dtype: int64

# %%
reviews["review_text"] = reviews["review_text"].fillna("NO review")

# %%
reviews.isnull().sum()
# Out:
# review_id         0
# order_id          0
# customer_id    2957
# product_id        0
# rating            0
# review_text       0
# review_date       0
# dtype: int64

# %%
reviews["customer_id"] = reviews["customer_id"].fillna("Unknowwn")

# %%
reviews.isnull().sum()
# Out:
# review_id      0
# order_id       0
# customer_id    0
# product_id     0
# rating         0
# review_text    0
# review_date    0
# dtype: int64

# %%
reviews.duplicated().sum()
# Out:
# np.int64(0)
