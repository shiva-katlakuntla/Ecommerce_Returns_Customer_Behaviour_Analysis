# %%
import pandas as pd
import numpy as np
import os

# %%
orders=pd.read_csv("/content/orders (1).csv")
orders
# Out:
#         order_id  customer_id       order_datetime order_status  order_amount  \
# 0        9000001       111988  2024-11-02 05:06:30     Returned       5246.69
# 1        9000002       108539  2025-02-14 15:58:37    Cancelled       4401.82
# 2        9000003       134618  2025-03-23 14:36:28    Delivered       5430.35
# 3        9000004       105961  2025-04-04 06:43:56    Cancelled       7872.25
# 4        9000005       116158  2024-10-18 08:54:04     Returned       4542.38
# ...          ...          ...                  ...          ...           ...
# 249995   9249996       110268  2025-04-07 08:31:54     Returned     276264.86
# 249996   9249997       140135  2026-11-14 03:20:36    Cancelled       4483.84
# 249997   9249998       133538  2025-03-25 01:05:38    Delivered     168152.21
# 249998   9249999       130159  2024-12-24 15:57:35    Delivered       3592.42
# 249999   9250000       103671  2025-03-29 18:00:05     Returned       5199.14
#
# ...

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_datetime            0
# order_status              0
# order_amount              0
# payment_method            0
# coupon_used               0
# delivery_city             0
# expected_delivery_date    0
# actual_delivery_date      0
# dtype: int64

# %%
display(orders[orders['order_id'] == 148299])
# Out:
# Empty DataFrame
# Columns: [order_id, customer_id, order_datetime, order_status, order_amount, payment_method, coupon_used, delivery_city, expected_delivery_date, actual_delivery_date]
# Index: []

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_datetime            0
# order_status              0
# order_amount              0
# payment_method            0
# coupon_used               0
# delivery_city             0
# expected_delivery_date    0
# actual_delivery_date      0
# dtype: int64

# %%
orders = orders[orders['order_id'] != 148299]

# %%
orders["coupon_used"].mode()
# Out:
# 0    Yes
# Name: coupon_used, dtype: object

# %%
orders['coupon_used'] = orders['coupon_used'].fillna(orders['coupon_used'].mode()[0])

# %%
orders.isnull().sum()
# Out:
# order_id                  0
# customer_id               0
# order_datetime            0
# order_status              0
# order_amount              0
# payment_method            0
# coupon_used               0
# delivery_city             0
# expected_delivery_date    0
# actual_delivery_date      0
# dtype: int64

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   order_id                250000 non-null  int64
#  1   customer_id             250000 non-null  int64
#  2   order_datetime          250000 non-null  object
#  3   order_status            250000 non-null  object
#  4   order_amount            250000 non-null  float64
#  5   payment_method          250000 non-null  object
#  6   coupon_used             250000 non-null  object
#  7   delivery_city           250000 non-null  object
#  8   expected_delivery_date  250000 non-null  object
#  9   actual_delivery_date    250000 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 19.1+ MB

# %%
orders["expected_delivery_date"] = pd.to_datetime(orders["expected_delivery_date"])

# %%
orders["actual_delivery_date"] = pd.to_datetime(orders["actual_delivery_date"])
orders['days_diff'] = (orders['actual_delivery_date'] - orders['expected_delivery_date']).dt.days

# %%
display(orders.head())
# Out:
#    order_id  customer_id       order_datetime order_status  order_amount  \
# 0   9000001       111988  2024-11-02 05:06:30     Returned       5246.69
# 1   9000002       108539  2025-02-14 15:58:37    Cancelled       4401.82
# 2   9000003       134618  2025-03-23 14:36:28    Delivered       5430.35
# 3   9000004       105961  2025-04-04 06:43:56    Cancelled       7872.25
# 4   9000005       116158  2024-10-18 08:54:04     Returned       4542.38
#
#   payment_method coupon_used delivery_city expected_delivery_date  \
# 0            COD         Yes       Chennai             2025-01-04
# 1            UPI         Yes     Hyderabad             2024-11-04
# 2           Card          No        Jaipur             2024-12-27
# 3            COD         Yes       Kolkata             2025-03-29
# 4         Wallet         Yes     Hyderabad             2021-06-09
#
#   actual_delivery_date  days_diff
# 0           2025-04-14        100
# 1           2025-04-02        149
# ...

# %%
days_mean = orders["days_diff"].median()
days_mean
# Out:
# 4.0

# %%
orders["days_diff"].value_counts()
# Out:
# days_diff
#  2       1439
#  5       1438
#  3       1389
#  4       1374
#  1       1372
#          ...
# -1764       1
# -1791       1
#  1771       1
#  1981       1
# -1884       1
# Name: count, Length: 4129, dtype: int64

# %%
orders[orders["days_diff"]>10].count()
# Out:
# order_id                  116905
# customer_id               116905
# order_datetime            116905
# order_status              116905
# order_amount              116905
# payment_method            116905
# coupon_used               116905
# delivery_city             116905
# expected_delivery_date    116905
# actual_delivery_date      116905
# days_diff                 116905
# dtype: int64
