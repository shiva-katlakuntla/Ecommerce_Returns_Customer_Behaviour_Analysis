# %%
import pandas as pd
import numpy as np

# %%
tickets = pd.read_csv("/content/customer_support_tickets.csv")
tickets
# Out:
#        ticket_id  customer_id   order_id    ticket_category  \
# 0        7500001       129434  9057422.0  Technical Support
# 1        7500002       149267        NaN         Wrong Item
# 2        7500003       116912  9179257.0     Return Request
# 3        7500004       132454  9249225.0     Return Request
# 4        7500005       138274  9132525.0     Delivery Issue
# ...          ...          ...        ...                ...
# 59995    7559996       148539  9141550.0    Product Quality
# 59996    7559997       148794  9115951.0    Product Quality
# 59997    7559998       113405  9110531.0         Wrong Item
# 59998    7559999       114124  9072539.0     Delivery Issue
# 59999    7560000       116853  9162811.0      Account Issue
#
#       ticket_created_date resolution_status  resolution_time_hours  \
# 0        25-01-2023 22:05          Resolved                     42
# 1        12-09-2023 19:38         Escalated                     -5
# ...

# %%
tickets.isnull().sum()
# Out:
# ticket_id                   0
# customer_id                 0
# order_id                 6101
# ticket_category          6050
# ticket_created_date         0
# resolution_status           0
# resolution_time_hours       0
# customer_sentiment       3581
# dtype: int64

# %%
tickets["resolution_status"].value_counts()
# Out:
# resolution_status
# Resolved     29981
# Open         16833
# Escalated     9018
# open          1794
# RESOLVED      1197
# Closed        1177
# Name: count, dtype: int64

# %%
tickets["resolution_status"] = tickets["resolution_status"].astype(str).str.title()

# %%
tickets["resolution_status"].value_counts()
# Out:
# resolution_status
# Resolved     31178
# Open         18627
# Escalated     9018
# Closed        1177
# Name: count, dtype: int64

# %%
tickets['ticket_category'] = tickets['ticket_category'].fillna('Unknown')
tickets['customer_sentiment'] = tickets['customer_sentiment'].fillna('Unknown')
tickets['order_id'] = tickets['order_id'].fillna('Unknown')

# %%
tickets.isnull().sum()
# Out:
# ticket_id                0
# customer_id              0
# order_id                 0
# ticket_category          0
# ticket_created_date      0
# resolution_status        0
# resolution_time_hours    0
# customer_sentiment       0
# dtype: int64

# %%
tickets.duplicated().sum()
# Out:
# np.int64(0)

# %%
tickets.shape
# Out:
# (60000, 8)
